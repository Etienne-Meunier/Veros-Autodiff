# %%
import jax.numpy as jnp
import jax

# %%
def step(x) : 
    return jnp.sin(x)

# %% [markdown]
# Forward

# %%
x_init = jnp.array((1.4))

x_final = jax.scan(x)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 3
#       1 x_init = jnp.array((1.4))
# ----> 3 x_final = jnp.scan(x)
#
# File ~/miniforge3/envs/veros/lib/python3.12/site-packages/jax/_src/deprecations.py:55, in deprecation_getattr.<locals>.getattr(name)
#      53   warnings.warn(message, DeprecationWarning, stacklevel=2)
#      54   return fn
# ---> 55 raise AttributeError(f"module {module!r} has no attribute {name!r}")
#
# AttributeError: module 'jax.numpy' has no attribute 'scan'
