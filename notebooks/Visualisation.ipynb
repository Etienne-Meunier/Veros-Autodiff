# %%
# %store -r dd

# %%
import treescope

# %%
 treescope.render_array(t, sliders=[2, 3])
# Out:
# <Arrayviz rendering>

# %%
 treescope.show(dd)
# Out:
# [
#   np.array((b'',), dtype=[('float0', 'V')]),
#   np.array((b'',), dtype=[('float0', 'V')]),
#   np.array((b'',), dtype=[('float0', 'V')]),
#   <jax.Array(0., dtype=float32)>,
#   np.array((b'',), dtype=[('float0', 'V')]),
#   <jax.Array float32(34,) ≈-2.6e-12 ±1.6e-12 [≥-4.7e-12, ≤8.8e-13] zero:2 nonzero:32>,
#   <jax.Array float32(34,) ≈2.9e-12 ±1.8e-12 [≥-9.2e-13, ≤7.7e-12] zero:3 nonzero:31>,
#   <jax.Array float32(46,) ≈-2.6e-12 ±9.1e-12 [≥-4e-11, ≤1.3e-11] zero:4 nonzero:42>,
#   <jax.Array float32(46,) ≈2.1e-12 ±7.9e-12 [≥-1.2e-11, ≤3.8e-11] zero:5 nonzero:41>,
#   <jax.Array float32(15,) ≈1.7e-12 ±3.9e-10 [≥-6e-10, ≤1.3e-09] nonzero:15>,
#   <jax.Array float32(15,) ≈-9.7e-14 ±2.7e-13 [≥-1.1e-12, ≤3.3e-15] zero:1 nonzero:14>,
#   <jax.Array float32(15,) ≈-1.8e-07 ±7.6e-07 [≥-3e-06, ≤1.1e-07] nonzero:15>,
#   <jax.Array float32(15,) ≈3.3e-08 ±1.3e-07 [≥-2.4e-08, ≤5.1e-07] nonzero:15>,
#   <jax.Array float32(46,) ≈-6.4e-07 ±2.1e-06 [≥-9.5e-06, ≤3e-06] zero:4 nonzero:42>,
# ...
