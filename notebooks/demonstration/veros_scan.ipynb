# %%
from __init__ import PRP; import sys
sys.path.append(PRP + 'veros/')

from datetime import datetime
from jax import config
config.update("jax_enable_x64", True)

import jax
sys.path.append(PRP)

from scripts.load_runtime import * #Setup parameters for veros 
from setups.acc.acc_learning import ACCSetup

import jax.numpy as jnp
from jax import vmap

from tqdm import tqdm
# Out:
# Differentiable Veros Experimental version
# Importing core modules
#  Using computational backend jax on cpu
#   Kernels are compiled during first iteration, be patient
#  Runtime settings are now locked

# %%
# Spin-up 
warmup_steps = 200
acc = ACCSetup()
acc.setup()
with acc.state.settings.unlock() :
    acc.state.settings.enable_eke = False

with acc.state.variables.unlock() :
     acc.state.variables.r_bot += 1e-5
     acc.state.variables.K_gm_0 += 1000.0

def ps(state) : 
    n_state = state.copy()
    acc.step(n_state)
    return n_state

step_jit = jax.jit(ps)

state = acc.state.copy() # Initial state
# Out:
# Running model setup
# Diffusion grid factor delta_iso1 = 0.01942284820457075

# %%
jax.lax.scan(lambda c, _ : (ps(c), _), state, length=5)
# Out:
# (VerosState(
#      settings = VerosSettings(
#          identifier = 'acc_learning',
#          description = 'My ACC setup',
#          nx = 30,
#          ny = 42,
#          nz = 15,
#          dt_mom = 4800.0,
#          dt_tracer = 43200.0,
#          runlen = 31536000.0,
#          AB_eps = 0.1,
#          x_origin = 0.0,
#          y_origin = -40.0,
#          pi = 3.141592653589793,
#          radius = 6370000.0,
#          degtom = 111177.4733520388,
#          omega = 7.292123516990375e-05,
#          rho_0 = 1024.0,
#          grav = 9.81,
#          coord_degree = True,
#          enable_cyclic_x = True,
#          eq_of_state_type = 3,
#          enable_implicit_vert_friction = True,
#          enable_explicit_vert_friction = False,
#          enable_hor_friction = True,
#          enable_hor_diffusion = False,
#          enable_biharmonic_friction = False,
#          enable_biharmonic_mixing = False,
#          enable_hor_friction_cos_scaling = True,
#          enable_ray_friction = False,
#          enable_bottom_friction = True,
#          enable_bottom_friction_var = False,
#          enable_quadratic_bottom_friction = False,
#          enable_tempsalt_sources = False,
#          enable_momentum_sources = False,
#          enable_superbee_advection = False,
#          enable_conserve_energy = True,
#          enable_store_bottom_friction_tke = False,
#          enable_store_cabbeling_heat = False,
#          enable_noslip_lateral = False,
#          enable_streamfunction = False,
#          A_h = 219872.23064520778,
#          K_h = 0.0,
#          r_ray = 0.0,
#          r_quad_bot = 0.0,
#          hor_friction_cosPower = 1.0,
#          A_hbi = 0.0,
#          K_hbi = 0.0,
#          biharmonic_friction_cosPower = 0.0,
#          kappaH_0 = 0.0,
#          kappaM_0 = 0.0,
#          enable_neutral_diffusion = True,
#          enable_skew_diffusion = True,
#          enable_TEM_friction = False,
#          K_iso_0 = 1000.0,
#          K_iso_steep = 500.0,
#          iso_dslope = 0.005,
#          iso_slopec = 0.01,
#          enable_idemix = False,
#          tau_v = 172800.0,
#          tau_h = 1296000.0,
#          gamma = 1.57,
#          jstar = 5.0,
#          mu0 = 0.3333333333333333,
#          enable_idemix_hor_diffusion = False,
#          enable_eke_diss_bottom = False,
#          enable_eke_diss_surfbot = False,
#          eke_diss_surfbot_frac = 1.0,
#          enable_idemix_superbee_advection = False,
#          enable_idemix_upwind_advection = False,
#          enable_tke = True,
#          c_k = 0.1,
#          c_eps = 0.7,
#          alpha_tke = 30.0,
#          mxl_min = 1e-08,
#          kappaM_min = 0.0002,
#          kappaM_max = 100.0,
#          tke_mxl_choice = 2,
#          enable_tke_superbee_advection = False,
#          enable_tke_upwind_advection = False,
#          enable_tke_hor_diffusion = False,
#          K_h_tke = 2000.0,
#          enable_eke = False,
#          eke_lmin = 100.0,
#          eke_c_k = 0.4,
#          eke_cross = 2.0,
#          eke_crhin = 1.0,
#          eke_c_eps = 0.5,
#          eke_k_max = 10000.0,
#          alpha_eke = 1.0,
#          enable_eke_superbee_advection = True,
#          enable_eke_upwind_advection = False,
#          enable_eke_isopycnal_diffusion = True,
#          restart_input_filename = None,
#          restart_output_filename = '{identifier}_{itt:0>4d}.restart.h5',
#          restart_frequency = 0.0,
#          kappaH_min = 2e-05,
#          enable_kappaH_profile = True,
#          enable_Prandtl_tke = True,
#          Prandtl_tke0 = 10.0
#      ),
#      dimensions = {'xt': 'nx', 'xu': 'nx', 'yt': 'ny', 'yu': 'ny', 'zt': 'nz', 'zw': 'nz', 'timesteps': 3, 'tensor1': 2, 'tensor2': 2, 'isle': 0},
#      variables = VerosVariables(
#          tau = <class 'jaxlib._jax.ArrayImpl'> with shape (), dtype int32,
#          taup1 = <class 'jaxlib._jax.ArrayImpl'> with shape (), dtype int32,
#          taum1 = <class 'jaxlib._jax.ArrayImpl'> with shape (), dtype int32,
#          time = <class 'jaxlib._jax.ArrayImpl'> with shape (), dtype float64,
#          itt = <class 'jaxlib._jax.ArrayImpl'> with shape (), dtype int32,
#          dxt = <class 'jaxlib._jax.ArrayImpl'> with shape (34,), dtype float64,
#          dxu = <class 'jaxlib._jax.ArrayImpl'> with shape (34,), dtype float64,
#          dyt = <class 'jaxlib._jax.ArrayImpl'> with shape (46,), dtype float64,
#          dyu = <class 'jaxlib._jax.ArrayImpl'> with shape (46,), dtype float64,
#          zt = <class 'jaxlib._jax.ArrayImpl'> with shape (15,), dtype float64,
#          zw = <class 'jaxlib._jax.ArrayImpl'> with shape (15,), dtype float64,
#          dzt = <class 'jaxlib._jax.ArrayImpl'> with shape (15,), dtype float64,
#          dzw = <class 'jaxlib._jax.ArrayImpl'> with shape (15,), dtype float64,
#          cost = <class 'jaxlib._jax.ArrayImpl'> with shape (46,), dtype float64,
#          cosu = <class 'jaxlib._jax.ArrayImpl'> with shape (46,), dtype float64,
#          tantr = <class 'jaxlib._jax.ArrayImpl'> with shape (46,), dtype float64,
#          coriolis_t = <class 'jaxlib._jax.ArrayImpl'> with shape (34, 46), dtype float64,
#          kbot = <class 'jaxlib._jax.ArrayImpl'> with shape (34, 46), dtype int64,
#          ht = <class 'jaxlib._jax.ArrayImpl'> with shape (34, 46), dtype float64,
#          hu = <class 'jaxlib._jax.ArrayImpl'> with shape (34, 46), dtype float64,
#          hv = <class 'jaxlib._jax.ArrayImpl'> with shape (34, 46), dtype float64,
#          hur = <class 'jaxlib._jax.ArrayImpl'> with shape (34, 46), dtype float64,
#          hvr = <class 'jaxlib._jax.ArrayImpl'> with shape (34, 46), dtype float64,
#          beta = <class 'jaxlib._jax.ArrayImpl'> with shape (34, 46), dtype float64,
#          area_t = <class 'jaxlib._jax.ArrayImpl'> with shape (34, 46), dtype float64,
#          area_u = <class 'jaxlib._jax.ArrayImpl'> with shape (34, 46), dtype float64,
#          area_v = <class 'jaxlib._jax.ArrayImpl'> with shape (34, 46), dtype float64,
#          maskT = <class 'jaxlib._jax.ArrayImpl'> with shape (34, 46, 15), dtype bool,
#          maskU = <class 'jaxlib._jax.ArrayImpl'> with shape (34, 46, 15), dtype bool,
#          maskV = <class 'jaxlib._jax.ArrayImpl'> with shape (34, 46, 15), dtype bool,
#          maskW = <class 'jaxlib._jax.ArrayImpl'> with shape (34, 46, 15), dtype bool,
#          maskZ = <class 'jaxlib._jax.ArrayImpl'> with shape (34, 46, 15), dtype bool,
#          rho = <class 'jaxlib._jax.ArrayImpl'> with shape (34, 46, 15, 3), dtype float64,
#          prho = <class 'jaxlib._jax.ArrayImpl'> with shape (34, 46, 15), dtype float64,
#          int_drhodT = <class 'jaxlib._jax.ArrayImpl'> with shape (34, 46, 15, 3), dtype float64,
#          int_drhodS = <class 'jaxlib._jax.ArrayImpl'> with shape (34, 46, 15, 3), dtype float64,
#          Nsqr = <class 'jaxlib._jax.ArrayImpl'> with shape (34, 46, 15, 3), dtype float64,
#          Hd = <class 'jaxlib._jax.ArrayImpl'> with shape (34, 46, 15, 3), dtype float64,
#          dHd = <class 'jaxlib._jax.ArrayImpl'> with shape (34, 46, 15, 3), dtype float64,
#          temp = <class 'jaxlib._jax.ArrayImpl'> with shape (34, 46, 15, 3), dtype float64,
#          dtemp = <class 'jaxlib._jax.ArrayImpl'> with shape (34, 46, 15, 3), dtype float64,
#          salt = <class 'jaxlib._jax.ArrayImpl'> with shape (34, 46, 15, 3), dtype float64,
#          dsalt = <class 'jaxlib._jax.ArrayImpl'> with shape (34, 46, 15, 3), dtype float64,
#          dtemp_vmix = <class 'jaxlib._jax.ArrayImpl'> with shape (34, 46, 15), dtype float64,
#          dtemp_hmix = <class 'jaxlib._jax.ArrayImpl'> with shape (34, 46, 15), dtype float64,
#          dsalt_vmix = <class 'jaxlib._jax.ArrayImpl'> with shape (34, 46, 15), dtype float64,
#          dsalt_hmix = <class 'jaxlib._jax.ArrayImpl'> with shape (34, 46, 15), dtype float64,
#          dtemp_iso = <class 'jaxlib._jax.ArrayImpl'> with shape (34, 46, 15), dtype float64,
#          dsalt_iso = <class 'jaxlib._jax.ArrayImpl'> with shape (34, 46, 15), dtype float64,
#          forc_temp_surface = <class 'jaxlib._jax.ArrayImpl'> with shape (34, 46), dtype float64,
#          forc_salt_surface = <class 'jaxlib._jax.ArrayImpl'> with shape (34, 46), dtype float64,
#          u = <class 'jaxlib._jax.ArrayImpl'> with shape (34, 46, 15, 3), dtype float64,
#          v = <class 'jaxlib._jax.ArrayImpl'> with shape (34, 46, 15, 3), dtype float64,
#          w = <class 'jaxlib._jax.ArrayImpl'> with shape (34, 46, 15, 3), dtype float64,
#          du = <class 'jaxlib._jax.ArrayImpl'> with shape (34, 46, 15, 3), dtype float64,
#          dv = <class 'jaxlib._jax.ArrayImpl'> with shape (34, 46, 15, 3), dtype float64,
#          du_cor = <class 'jaxlib._jax.ArrayImpl'> with shape (34, 46, 15), dtype float64,
#          dv_cor = <class 'jaxlib._jax.ArrayImpl'> with shape (34, 46, 15), dtype float64,
#          du_mix = <class 'jaxlib._jax.ArrayImpl'> with shape (34, 46, 15), dtype float64,
#          dv_mix = <class 'jaxlib._jax.ArrayImpl'> with shape (34, 46, 15), dtype float64,
#          du_adv = <class 'jaxlib._jax.ArrayImpl'> with shape (34, 46, 15), dtype float64,
#          dv_adv = <class 'jaxlib._jax.ArrayImpl'> with shape (34, 46, 15), dtype float64,
#          p_hydro = <class 'jaxlib._jax.ArrayImpl'> with shape (34, 46, 15), dtype float64,
#          kappaM = <class 'jaxlib._jax.ArrayImpl'> with shape (34, 46, 15), dtype float64,
#          kappaH = <class 'jaxlib._jax.ArrayImpl'> with shape (34, 46, 15), dtype float64,
#          surface_taux = <class 'jaxlib._jax.ArrayImpl'> with shape (34, 46), dtype float64,
#          surface_tauy = <class 'jaxlib._jax.ArrayImpl'> with shape (34, 46), dtype float64,
#          forc_rho_surface = <class 'jaxlib._jax.ArrayImpl'> with shape (34, 46), dtype float64,
#          ssh = <class 'jaxlib._jax.ArrayImpl'> with shape (34, 46), dtype float64,
#          psi = <class 'jaxlib._jax.ArrayImpl'> with shape (34, 46, 3), dtype float64,
#          K_gm_0 = <class 'jaxlib._jax.ArrayImpl'> with shape (), dtype float64,
#          K_gm = <class 'jaxlib._jax.ArrayImpl'> with shape (34, 46, 15), dtype float64,
#          K_iso = <class 'jaxlib._jax.ArrayImpl'> with shape (34, 46, 15), dtype float64,
#          K_diss_v = <class 'jaxlib._jax.ArrayImpl'> with shape (34, 46, 15), dtype float64,
#          K_diss_bot = <class 'jaxlib._jax.ArrayImpl'> with shape (34, 46, 15), dtype float64,
#          K_diss_h = <class 'jaxlib._jax.ArrayImpl'> with shape (34, 46, 15), dtype float64,
#          K_diss_gm = <class 'jaxlib._jax.ArrayImpl'> with shape (34, 46, 15), dtype float64,
#          P_diss_v = <class 'jaxlib._jax.ArrayImpl'> with shape (34, 46, 15), dtype float64,
#          P_diss_nonlin = <class 'jaxlib._jax.ArrayImpl'> with shape (34, 46, 15), dtype float64,
#          P_diss_iso = <class 'jaxlib._jax.ArrayImpl'> with shape (34, 46, 15), dtype float64,
#          P_diss_skew = <class 'jaxlib._jax.ArrayImpl'> with shape (34, 46, 15), dtype float64,
#          P_diss_hmix = <class 'jaxlib._jax.ArrayImpl'> with shape (34, 46, 15), dtype float64,
#          P_diss_adv = <class 'jaxlib._jax.ArrayImpl'> with shape (34, 46, 15), dtype float64,
#          P_diss_sources = <class 'jaxlib._jax.ArrayImpl'> with shape (34, 46, 15), dtype float64,
#          r_bot = <class 'jaxlib._jax.ArrayImpl'> with shape (), dtype float64,
#          u_wgrid = <class 'jaxlib._jax.ArrayImpl'> with shape (34, 46, 15), dtype float64,
#          v_wgrid = <class 'jaxlib._jax.ArrayImpl'> with shape (34, 46, 15), dtype float64,
#          w_wgrid = <class 'jaxlib._jax.ArrayImpl'> with shape (34, 46, 15), dtype float64,
#          xt = <class 'jaxlib._jax.ArrayImpl'> with shape (34,), dtype float64,
#          xu = <class 'jaxlib._jax.ArrayImpl'> with shape (34,), dtype float64,
#          yt = <class 'jaxlib._jax.ArrayImpl'> with shape (46,), dtype float64,
#          yu = <class 'jaxlib._jax.ArrayImpl'> with shape (46,), dtype float64,
#          K_11 = <class 'jaxlib._jax.ArrayImpl'> with shape (34, 46, 15), dtype float64,
#          K_22 = <class 'jaxlib._jax.ArrayImpl'> with shape (34, 46, 15), dtype float64,
#          K_33 = <class 'jaxlib._jax.ArrayImpl'> with shape (34, 46, 15), dtype float64,
#          Ai_ez = <class 'jaxlib._jax.ArrayImpl'> with shape (34, 46, 15, 2, 2), dtype float64,
#          Ai_nz = <class 'jaxlib._jax.ArrayImpl'> with shape (34, 46, 15, 2, 2), dtype float64,
#          Ai_bx = <class 'jaxlib._jax.ArrayImpl'> with shape (34, 46, 15, 2, 2), dtype float64,
#          Ai_by = <class 'jaxlib._jax.ArrayImpl'> with shape (34, 46, 15, 2, 2), dtype float64,
#          B1_gm = <class 'jaxlib._jax.ArrayImpl'> with shape (34, 46, 15), dtype float64,
#          B2_gm = <class 'jaxlib._jax.ArrayImpl'> with shape (34, 46, 15), dtype float64,
#          tke = <class 'jaxlib._jax.ArrayImpl'> with shape (34, 46, 15, 3), dtype float64,
#          sqrttke = <class 'jaxlib._jax.ArrayImpl'> with shape (34, 46, 15), dtype float64,
#          dtke = <class 'jaxlib._jax.ArrayImpl'> with shape (34, 46, 15, 3), dtype float64,
#          Prandtlnumber = <class 'jaxlib._jax.ArrayImpl'> with shape (34, 46, 15), dtype float64,
#          mxl = <class 'jaxlib._jax.ArrayImpl'> with shape (34, 46, 15), dtype float64,
#          forc_tke_surface = <class 'jaxlib._jax.ArrayImpl'> with shape (34, 46), dtype float64,
#          tke_diss = <class 'jaxlib._jax.ArrayImpl'> with shape (34, 46, 15), dtype float64,
#          tke_surf_corr = <class 'jaxlib._jax.ArrayImpl'> with shape (34, 46), dtype float64,
#          eke = <class 'jaxlib._jax.ArrayImpl'> with shape (34, 46, 15, 3), dtype float64,
#          deke = <class 'jaxlib._jax.ArrayImpl'> with shape (34, 46, 15, 3), dtype float64,
#          sqrteke = <class 'jaxlib._jax.ArrayImpl'> with shape (34, 46, 15), dtype float64,
#          L_rossby = <class 'jaxlib._jax.ArrayImpl'> with shape (34, 46), dtype float64,
#          L_rhines = <class 'jaxlib._jax.ArrayImpl'> with shape (34, 46, 15), dtype float64,
#          eke_len = <class 'jaxlib._jax.ArrayImpl'> with shape (34, 46, 15), dtype float64,
#          eke_diss_iw = <class 'jaxlib._jax.ArrayImpl'> with shape (34, 46, 15), dtype float64,
#          eke_diss_tke = <class 'jaxlib._jax.ArrayImpl'> with shape (34, 46, 15), dtype float64,
#          t_star = <class 'jaxlib._jax.ArrayImpl'> with shape (46,), dtype float64,
#          t_rest = <class 'jaxlib._jax.ArrayImpl'> with shape (34, 46), dtype float64
#      ),
#      diagnostics = {},
#      plugin_interfaces = ()
#  ),
#  None)
